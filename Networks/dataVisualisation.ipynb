# %%
from Utils.Data import provideData
from nn_Setup import cnnLSTM_config as cnnConf
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
import numpy as np
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
trainset,testset = provideData(cnnConf.DIMENSION,
                    1,
                    cnnConf.INPUT_CHANNELS,
                    preTransformation=cnnConf.PRETRAINING_TRANSFORMATIONS,
                    transform=cnnConf.TRANSFORMATIONS)

dimension = cnnConf.DIMENSION
# Out:
# Found Year :  2017 => won't download this year again... please check for consistency
# Finished Loading Dataset

# %%
#X,Y = trainset[10]
X = None
Y = None
#trainset.on_epoch_end()

for i,(x,y) in enumerate(trainset):
    if len(np.where(x>0)[0]) > 4000:
        X = x
        Y = y
        print(i)
        break



fig, axes = plt.subplots(cnnConf.BATCHSIZE, cnnConf.INPUT_CHANNELS+1, figsize=(128, 128),dpi=100, sharex=True, sharey=True)

for batch,img in enumerate(X):
    for i in range(cnnConf.INPUT_CHANNELS):
        image = img[:,:,i]
        axes[batch,i].imshow(image,cmap="gray")
    
    axes[batch,-1].imshow(Y[batch,:,:,0],cmap="gray")
# Out:
# 416

# %%
nbrInfos = 0
fullnbr = 0
for x,y in trainset:
    bsize,_,_,_ = y.shape
    for b in range(bsize):
        fullnbr += 1
        if y[b].max() > 0:
            nbrInfos += 1
# Out:
#  78822 10 78840
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/gitprojects/DeepRain2/Networks/Utils/Data.py in __data_generation(self, index)
#     332         try:
# --> 333             label = np.array(Image.open(self.listOfFiles[index+self.label_offset]))
#     334
#
# ~/anaconda3/envs/tensorflow-gpu/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2769     if filename:
# -> 2770         fp = builtins.open(filename, "rb")
#    2771         exclusive_fp = True
#
# FileNotFoundError: [Errno 2] No such file or directory: './Data/train/256x320_256x320/1710011720.png'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f265d267ffd3> in <module>
#       1 nbrInfos = 0
#       2 fullnbr = 0
# ----> 3 for x,y in trainset:
# ...

# %%
print("Daten die Informationen enthalten: {:.2f} %".format((nbrInfos/fullnbr)*100))

# %%
arr = np.zeros((*cnnConf.DIMENSION,256))

def addTOarr(img):
    x_,y_,_ = img.shape
    
    for i in range(x_):
        for j in range(y_):
            arr[i,j,int(img[i,j,0])] += 1
        
for x,y in trainset:
    batchsize,_,_,_ = y.shape
    for i in range(batchsize):
        addTOarr(y[i,:,:,:])

# %%
xs = randrange(n, 0, 64)
ys = randrange(n, 0, 255)
zs = arr[0,:,:]

X = np.arange(0, 256, 1)
Y = np.arange(0, 256, 1)
xs, ys = np.meshgrid(X, Y)

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

zs = zs.transpose((1,0))

print(xs.shape)
print(ys.shape)
print(zs.shape)



print(xs)
print(ys)
print(zs)


ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

# Plot the surface.
#surf = ax.plot_surface(X, Y, zs, cmap=cm.coolwarm,
#                       linewidth=0, antialiased=False)
ax.plot_wireframe(X, Y, zs, rstride=10, cstride=10)

plt.show()
# Customize the z axis.
#ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Grab some test data.
X, Y, Z = axes3d.get_test_data(0.05)
print(X.shape)
print(Y.shape)
print(Z.shape)
# Plot a basic wireframe.
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

plt.show()




print(X)
print(Y)
print(Z)

# %%
'''
==============
3D scatterplot
==============

Demonstration of a basic scatterplot in 3D.
'''

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np


def randrange(n, vmin, vmax):
    '''
    Helper function to make an array of random numbers having shape (n, )
    with each number distributed Uniform(vmin, vmax).
    '''
    return (vmax - vmin)*np.random.rand(n) + vmin

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

n = 100

# For each set of style and range settings, plot n random points in the box
# defined by x in [23, 32], y in [0, 100], z in [zlow, zhigh].
for c, m, zlow, zhigh in [('r', 'o', -50, -25), ('b', '^', -30, -5)]:
    xs = randrange(n, 23, 32)
    ys = randrange(n, 0, 100)
    zs = randrange(n, zlow, zhigh)
    ax.scatter(xs, ys, zs, c=c, marker=m)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()
print(xs.shape)
print(ys.shape)
print(zs.shape)

# %%
"""
========================================
Create 2D bar graphs in different planes
========================================

Demonstrates making a 3D plot which has 2D bar graphs projected onto
planes y=0, y=1, etc.
"""

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):
    xs = np.arange(20)
    ys = np.random.rand(20)

    # You can provide either a single color or an array. To demonstrate this,
    # the first bar of each set will be colored cyan.
    cs = [c] * len(xs)
    cs[0] = 'c'
    ax.bar(xs, ys, zs=z, zdir='y', color=cs, alpha=0.8)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')

plt.show()
print(xs.shape)
print(ys.shape)
print(zs.shape)

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(0, 10, 1)
Y = np.arange(0, 10, 1)
X, Y = np.meshgrid(X, Y)

print(X)

print(Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

print(Z)

print(X.shape)
print(Y.shape)
print(Z.shape)
# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
