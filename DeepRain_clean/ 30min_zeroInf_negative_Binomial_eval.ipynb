# %%
from min30_zeroInf_negative_Binomial import *
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
from PIL import Image
import numpy as np
import seaborn as sns
import pandas as pd
from matplotlib import pyplot
from Utils.eval import *
from tensorflow.keras.optimizers import Adam
import keras.backend.tensorflow_backend
from keras.backend import clear_session
from tensorflow.keras.models import Model,Sequential
# Out:
# Num GPUs: 1
# Using TensorFlow backend.

# %%
source_model,modelpath,train,test = getModel(False)
source_model.summary()
predictions = source_model.layers[-2].output
model = Model(inputs=source_model.inputs, outputs=predictions)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 5)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 20)   920         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 96, 20)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 20)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 25)   4525        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 25)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 25)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 25)   5650        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 25)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 25)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 25)   5650        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12, 12, 25)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 25)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 12, 12, 25)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12, 12, 50)   0           activation_3[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 24, 24, 50)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 24, 75)   0           activation_2[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 48, 48, 75)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 48, 48, 100)  0           activation_1[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 96, 96, 100)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96, 96, 120)  0           activation[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 94, 94, 6)    6486        concatenate_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None, 94, 94, 2)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None, 94, 94, 2)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(None, 94, 94, 2)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 17672)        0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 17672)        0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 17672)        0           tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          9048576     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          9048576     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          9048576     flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4096)         2101248     dense[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4096)         2101248     dense_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4096)         2101248     dense_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 64, 1)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 64, 64, 1)    0           dense_4[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 64, 64, 1)    0           dense_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ConcatLayer (Tensor [(None, 64, 64, 3)]  0           reshape[0][0]
#                                                                  reshape_1[0][0]
#                                                                  reshape_2[0][0]
# __________________________________________________________________________________________________
# DistributionLayer (Distribution ((None, 64, 64, 1),  0           tf_op_layer_ConcatLayer[0][0]
# ==================================================================================================
# Total params: 33,472,703
# Trainable params: 33,472,703
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 96, 5)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 20)   920         input_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 96, 20)   0           conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 48, 48, 20)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 48, 48, 25)   4525        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 25)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 25)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 24, 24, 25)   5650        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 25)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 25)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 12, 12, 25)   5650        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 12, 12, 25)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 25)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 12, 12, 25)   0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 12, 12, 50)   0           activation_3[0][0]
#                                                                  up_sampling2d[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 24, 24, 50)   0           concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 24, 75)   0           activation_2[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 48, 48, 75)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 48, 48, 100)  0           activation_1[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 96, 96, 100)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96, 96, 120)  0           activation[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 94, 94, 6)    6486        concatenate_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice (Tens [(None, 94, 94, 2)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_1 (Te [(None, 94, 94, 2)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_strided_slice_2 (Te [(None, 94, 94, 2)]  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 17672)        0           tf_op_layer_strided_slice[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 17672)        0           tf_op_layer_strided_slice_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 17672)        0           tf_op_layer_strided_slice_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          9048576     flatten[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          9048576     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 512)          9048576     flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4096)         2101248     dense[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 4096)         2101248     dense_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4096)         2101248     dense_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 64, 64, 1)    0           dense_3[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 64, 64, 1)    0           dense_4[0][0]
# __________________________________________________________________________________________________
# reshape_2 (Reshape)             (None, 64, 64, 1)    0           dense_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_ConcatLayer (Tensor [(None, 64, 64, 3)]  0           reshape[0][0]
#                                                                  reshape_1[0][0]
#                                                                  reshape_2[0][0]
# ==================================================================================================
# Total params: 33,472,703
# Trainable params: 33,472,703
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history_path = os.path.join(modelpath,MODELNAME+"_history.png")
figure(num=None, figsize=(10, 30), dpi=80, facecolor='w', edgecolor='k')
loss = np.array(Image.open(history_path))
plt.imshow(loss)
plt.axis('off')
plt.show()
y_transform = [cutOut([16,80,16,80])]

# %%
history_path = os.path.join(modelpath,MODELNAME+"_history")
laststate = getBestState(modelpath,history_path)
epoch = laststate["epoch"]
model.load_weights(laststate["modelpath"])
test.setWiggle_off()

# %%
def getFreshSet(batch_size=1):
    #x_transform = [Normalize(0.007742631458799244, 0.015872015890555563 )]
    
    train,test = getData(batch_size,
                         DIMENSION,CHANNELS,
                         timeToPred=30,
                         y_transform=y_transform)
    return train,test

# %%
from Models.Distributions import ZeroInflated_Binomial
pred = None
label = None
pred = 20
#test.on_epoch_end()
mean = []
stdev = []
label = []
predictions = []
train,test = getFreshSet(50)

test.setWiggle_off()
atm = []
for x,y in test:
    for i in range(BATCH_SIZE):
        if i < 10:
            continue
        pred = model(np.array([x[i,:,:,:]]))
        pred = ZeroInflated_Binomial()(pred)
        mean.append(pred.mean())
        stdev.append(pred.stddev())
        label.append(y[i,:,:,:])
        predictions.append((pred,y[i:,:,:]))
        atm.append(x[i,:,:,-1:])
        if len(label) == 20:
            break
    break
    if len(label) == 20:
                break

# %%
sns.set(style="white")
#sns.set_style("darkgrid")
fig, axes = plt.subplots(20, 4, figsize=(16,8*10),dpi=64)
#fig.set_title(["mean","stdev","label"])
for batch,img in enumerate(mean):
    if batch == 20:
        break
    axes[batch,2].imshow(img[0,:,:,0],cmap="gray")
    axes[batch,3].imshow(stdev[batch][0,:,:,0],cmap="gray")
    axes[batch,1].imshow(label[batch][:,:,0],cmap="gray")
    axes[batch,0].imshow(atm[batch][:,:,-1],cmap="gray")
plt.show()

# %%
train,test =  getFreshSet(batch_size=100)

# %%
baseline = multiProc_eval(model,test,getFreshSet,x_transform=y_transform)
# Out:
# Worker  3 finishedd   2200 imagesing to sleep for 5s
# Worker  1 finishedd   2200 images
# Worker  0 finishedd   2200 imagesing to sleep for 5s
# Worker  4 finishedd   2200 imagesing to sleep for 5s
# Worker  2 finishedd   2200 images
# Worker  5 finishedd   2200 imagesing to sleep for 5s
# Worker  6 finishedd   2200 images
# Worker 11 finishedd   2200 images
# Worker  7 finishedd   2200 imagesing to sleep for 5s
# Worker  8 finishedd   2200 images
# Worker  9 finishedd   2200 images
# Worker 10 finishedd   2200 images
# Worker 12 finishedd   2200 imagesing to sleep for 5s
# Worker 13 finishedd   2200 images
# Worker 14 finishedd   2200 imagesing to sleep for 5s
# Worker 15 finishedd   2200 images
# Worker 16 finishedd   2200 imagesing to sleep for 5s
# Worker 17 finishedd   2200 images
# Worker 18 finishedd   2200 images
# Worker 19 finishedd   2200 imagesing to sleep for 5s
# Worker 20 finishedd   2200 imagesing to sleep for 5s
# Worker 21 finishedd   2200 imagesing to sleep for 5s
# Worker 22 finishedd   2200 imagesing to sleep for 5s
# Worker 23 finishedd   2200 images
# Worker 24 finishedd   2200 imagesing to sleep for 5s
# Worker 26 finishedd   2200 images
# Worker 25 finishedd   2200 images
# Worker 27 finishedd   2200 images
# Worker 29 finishedd   2200 images
# Worker 28 finishedd   2200 images
# Worker 30 finishedd   2200 images
# Worker 33 finishedd   2200 images
# Worker 34 finishedd   2200 images
# Worker 31 finishedd   2200 images
# Worker 35 finishedd   2200 images
# Worker 32 finishedd   2200 images
# Worker 36 finishedd   2200 images
# Worker 37 finishedd   2200 images
# Worker 38 finishedd   2200 images
# Worker 42 finishedd   2200 images
# Worker 40 finishedd   2200 images
# Worker 39 finishedd   2200 images
# Worker 41 finishedd   2200 images
# Worker 43 finishedd   2200 images
# Worker 44 finishedd   2200 images
# Worker 45 finishedd   2200 images
# Worker 46 finishedd   2200 images

# %%
baseline_dict = baseline.copy()
plotAUC(baseline_dict)

# %%
print(baseline_dict)
# Out:
# {0: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 1: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 2: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 3: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 4: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 5: {'TP': 55418353.0, 'TN': 291089495.0, 'FP': 72117025.0, 'FN': 4901527.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 6: {'TP': 50134519.0, 'TN': 322575587.0, 'FP': 40630933.0, 'FN': 10185361.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 7: {'TP': 48186845.0, 'TN': 328294461.0, 'FP': 34912059.0, 'FN': 12133035.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 8: {'TP': 46060169.0, 'TN': 333787784.0, 'FP': 29418736.0, 'FN': 14259711.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 9: {'TP': 43046498.0, 'TN': 340163158.0, 'FP': 23043362.0, 'FN': 17273382.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 10: {'TP': 34432747.0, 'TN': 354311379.0, 'FP': 8895141.0, 'FN': 25887133.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 11: {'TP': 30308492.0, 'TN': 356866019.0, 'FP': 6340501.0, 'FN': 30011388.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 12: {'TP': 21675587.0, 'TN': 359738541.0, 'FP': 3467979.0, 'FN': 38644293.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 13: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 14: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 15: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 16: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 17: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 18: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 3 ...

# %%
def quantile(prediction,iv = (0,128),cfdi = 0.90):
    shape = prediction.sample().shape
    q = np.zeros((*shape[:-1],3),dtype=np.float32)
    a         = np.arange(iv[0],iv[1])
        
    prob = prediction.prob(a)
    cdf  = np.cumsum(prob,axis=-1)
    mean = prediction.mean()
 
    intervall = (cdf >= 1 - cfdi) & (cdf <=  cfdi)
    
    _,x,y,_ = shape
    
    x, y = np.meshgrid(np.arange(0,x),np.arange(0,y), sparse=False, indexing='ij')
    

    for i in range(shape[1]):
        for j in range(shape[2]):
            idcs   = np.where(intervall[0,i,j]==True)[0] 
            lower  = idcs[0]
            upper  = idcs[-1]
            q[0,i,j] = [lower,mean[0,i,j],upper]
            
            
    return q

def nBinom(t):
    
    return tfp.distributions.Independent(
                    tfp.distributions.NegativeBinomial(
                    total_count=tf.math.softplus(t[...,1:]), \
                    logits=tf.math.sigmoid(t[...,:1]))
        ,name="ZeroInflated_Binomial",reinterpreted_batch_ndims=0)




def calculate_quantiles(model,test,max_j=30):
    
    quantiles = []
    label     = []
    #test.on_epoch_end()
    batch_size = test[0][0].shape[0]
    length = len(test)
    for j,(x,y) in enumerate(test):
        
        if j >= max_j:
            return (quantiles,label)
        
        print("{}/{}".format(j,length),end="\r")
        for i in range(batch_size):
            pred = model(np.array([x[i,:,:,:]]))
            quantiles.append(quantile(nBinom(pred[...,1:])))
            label.append(y[i,:,:,:])
            
        
        
            
    return (quantiles,label)

ret = calculate_quantiles(model,test,max_j=5)
q,l = ret
# Out:
# 4/1043

# %%
plotCFDI(q[:60],l[:60])
# Out:
# /home/simon/Dokumente/Teamprojekt/DeepRain2/DeepRain_clean/Utils/eval.py:469: MatplotlibDeprecationWarning: The parameter where must have the same size as x in fill_between(). This will become an error in future versions of Matplotlib.
#   ax.fill_between(x, lower, upper, where=upper >= lower, facecolor='green', alpha=0.1,interpolate=True)

# %%
hist,hist_q = histogramm(q,l)

# %% [markdown]
# # Wie oft liegen wir im 90% quantil?

# %%
    
plotHist(hist,hist_q)

# %%
print("Anzahl an labels           :",hist.sum())
print("Anzahl liegt im C-Intervall {} | {:.2f}:".format(hist_q.sum(),hist_q.sum()/hist.sum()))
print("\nOhne Regen")
print("Anzahl an labels           :",hist[1:].sum())
print("Anzahl liegt im C-Intervall: {} | {:.2f}%".format(hist_q[1:].sum(),hist_q[1:].sum()/hist[1:].sum()))
# Out:
# Anzahl an labels           : 2048000.0
# Anzahl liegt im C-Intervall 1842054.0 | 0.90:
#
# Ohne Regen
# Anzahl an labels           : 343334.0
# Anzahl liegt im C-Intervall: 137388.0 | 0.40%

# %%
def plotConfusionMat(baseline,t):
    
    
    print("Parameter : {:.2f}".format(t/20))
    baseline = baseline[t]
    false_neg = baseline["FN"]
    false_pos = baseline["FP"]
    true_pos = baseline["TP"]
    true_neg = baseline["TN"]
    
    simple_false_neg = baseline["FN_simple"]
    simple_false_pos = baseline["FP_simple"]
    simple_true_pos = baseline["TP_simple"]
    simple_true_neg = baseline["TN_simple"]
    
    
    plt.figure(figsize = (4,4))

    #mat = np.array([[false_neg.sum(),false_pos.sum()],[true_neg.sum(),true_pos.sum()]])
    mat = np.array([[true_neg.sum(),false_pos.sum()],[false_neg.sum(),true_pos.sum()]])
    total = mat.sum()
    df_cm = pd.DataFrame(mat/total,index = ["Actual 0","Actual 1"],columns=["Predicted 0","Predicted 1"])
    sns.heatmap(df_cm, annot=True,vmin=0.0, vmax=1.0)
    plt.show()
    
    plt.figure(figsize = (4,4))
    print("Simple Baseline")
    mat_simple = np.array([[simple_true_neg.sum(),simple_false_pos.sum()],[simple_false_neg.sum(),simple_true_pos.sum()]])
    total = mat.sum()
    df_cm = pd.DataFrame(mat_simple/total,index = ["Actual 0","Actual 1"],columns=["Predicted 0","Predicted 1"])
    sns.heatmap(df_cm, annot=True,vmin=0.0, vmax=1.0)
    plt.show()

    print(len(baseline))
    
plotConfusionMat(baseline_dict,t=10)
# Out:
# Parameter : 0.50
# Simple Baseline
# 10

# %%
def nBinom(t):
    
    return tfp.distributions.Independent(
                    tfp.distributions.NegativeBinomial(
                    total_count=tf.math.softplus(t[...,1:]), \
                    logits=tf.math.sigmoid(t[...,:1]))
        ,name="ZeroInflated_Binomial",reinterpreted_batch_ndims=0)


def getDist(param,dist,iv=(0,255)):
    prediction = dist(param)
    prob = np.array(prediction.sample(255))
    prob = prob.transpose(1,2,3,4,0)
    
    return prob[:,:,:,0,:]
    

def joyplot(model,test,max_j = 2):
    y = test[0][1]
    x_,y_ = np.random.randint(low=0,high=y.shape[1],size=2)

    dists = []
    time_d  = []
    x_series = []

    for j,(x,y) in enumerate(test):
        
        if j >= max_j:
            break
        batch_size = x.shape[0]
        for i in range(batch_size):
            pred = model(np.array([x[i,:,:,:]]))
            d = getDist(pred[:,:,:,1:],nBinom)
            dists.append(np.array(d[0,x_,y_,1:]))
            x_series.append(np.arange(0,255))
            
    import joypy
    dframe = pd.DataFrame(np.array(dists[:50]).T)
    fig, axes = joypy.joyplot(dframe,
                              figsize=(5,10),
                              linewidth=0.5,
                              grid='y',
                              background='k',
                              x_range=[1,50],
                              colormap=cm.rainbow)
    plt.show()
    
joyplot(model,test)

# %%
from keras.utils.vis_utils import plot_model

plot_model(
    model, to_file='model.png', show_shapes=False, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-29-f28935f6bb33> in <module>
#       3 plot_model(
#       4     model, to_file='model.png', show_shapes=False, show_layer_names=True,
# ----> 5     rankdir='TB', expand_nested=False, dpi=96
#       6 )
#
# ~/anaconda3/envs/DeepRain/lib/python3.7/site-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir, expand_nested, dpi)
#     238     """
#     239     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir,
# --> 240                        expand_nested, dpi)
#     241     _, extension = os.path.splitext(to_file)
#     242     if not extension:
#
# ~/anaconda3/envs/DeepRain/lib/python3.7/site-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir, expand_nested, dpi, subgraph)
#      77     from ..models import Sequential
#      78
# ---> 79     _check_pydot()
#      80     if subgraph:
#      81         dot = pydot.Cluster(style='dashed', graph_name=model.name)
#
# ~/anaconda3/envs/DeepRain/lib/python3.7/site-packages/keras/utils/vis_utils.py in _check_pydot()
#      20     if pydot is None:
#      21         raise ImportError(
# ---> 22             'Failed to import `pydot`. '
#      23             'Please install `pydot`. '
#      24             'For example with `pip install pydot`.')
#
# ImportError: Failed to import `pydot`. Please install `pydot`. For example with `pip install pydot`.
