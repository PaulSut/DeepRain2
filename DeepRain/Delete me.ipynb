# %%
import os
import json

# %%
import numpy as np
a = [1.76999703e+08, 4.04408500e+06, 1.04607510e+07, 8.31433800e+06,
 4.04443200e+06, 1.13336200e+06, 1.00000000e+03]
b = [1.723879301e+08, 1.12000000e+02, 2.22590100e+06, 2.72527900e+06,
 8.42573000e+05, 9.48470000e+04, 0.0]

c = np.array(b)/np.array(a)
for i,t in enumerate(c):
    print("Klasse {} | {:.2f}".format(i,t))
# Out:
# Klasse 0 | 0.97
# Klasse 1 | 0.00
# Klasse 2 | 0.21
# Klasse 3 | 0.33
# Klasse 4 | 0.21
# Klasse 5 | 0.08
# Klasse 6 | 0.00

# %%
a = [1.7999703e+08, 4.04408500e+06, 1.04607510e+07, 8.31433800e+06,
 4.04443200e+06, 1.13336200e+06, 8.12900000e+03] 
b = [1.72349601e+08, 1.20000000e+01, 2.38106400e+06, 2.79673300e+06,
 8.18647000e+05, 7.24090000e+04, 0.00000000e+00]

c = np.array(b)/np.array(a)
for i,t in enumerate(c):
    print("Klasse {} | {:.2f}".format(i,t))
# Out:
# Klasse 0 | 0.97
# Klasse 1 | 0.00
# Klasse 2 | 0.23
# Klasse 3 | 0.34
# Klasse 4 | 0.20
# Klasse 5 | 0.06
# Klasse 6 | 0.00

# %%
a = [8.786387e+06, 1.861010e+05, 4.924440e+05, 4.397330e+05, 2.496640e+05,
 8.887700e+04, 8.900000e+02]

b = [8525909.,   19000.,  201636.,  151569.,   17684.,       0.,       0.]
c = np.array(b)/np.array(a)
for i,t in enumerate(c):
    print("Klasse {} | {:.2f}".format(i,t))
# Out:
# Klasse 0 | 0.97
# Klasse 1 | 0.10
# Klasse 2 | 0.41
# Klasse 3 | 0.34
# Klasse 4 | 0.07
# Klasse 5 | 0.00
# Klasse 6 | 0.00

# %%
a = [8.79378e+06, 1.83847e+05, 4.87263e+05, 4.37299e+05, 2.50428e+05, 9.07130e+04,
 7.66000e+02] 
b = [8526904.,   18827.,  203736.,  130493.,   13069.,       0.,       0.]

c = np.array(b)/np.array(a)
for i,t in enumerate(c):
    print("Klasse {} | {:.2f}".format(i,t))
# Out:
# Klasse 0 | 0.97
# Klasse 1 | 0.10
# Klasse 2 | 0.42
# Klasse 3 | 0.30
# Klasse 4 | 0.05
# Klasse 5 | 0.00
# Klasse 6 | 0.00

# %%
Model1 = "30min_LSTM_znBinomial"
Model2 = "zeroInf_negative_Binomial"
pwd = "Models_weights"

# %%
first = os.path.join(pwd,Model1)
second = os.path.join(pwd,Model2)

# %%
hist_first = os.path.join(first,Model1+"_history.json")
hist_second = os.path.join(second,Model2+"_history.json")

# %%
lstm = json.load(open(hist_first))
unet = json.load(open(hist_second))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.pyplot import figure
axis_font = {'size':'25'}

# %%
sns.set(style="darkgrid")
plt.figure(figsize=(20, 10),dpi=100)
#plt.rcParams["font.family"] = "Times New Roman"
size=25
lw = 3
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (20,8),
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size,
          'ytick.labelsize': size,
          'axes.titlepad': 25}
plt.rcParams.update(params)

plt.plot(lstm['loss'][:35],label="LSTM train",lw=lw,color="blue")
plt.plot(lstm['val_loss'][:35],label="LSTM test",lw=lw,linestyle="--",color="blue")
plt.plot(unet['loss'][:35],label="Unet train",lw=lw,color="green")
plt.plot(unet['val_loss'][:35],label="Unet test",lw=lw,linestyle="--",color="green")
plt.title("Zero-Inflated negative Binomial")

#plt.xlim([0, 35])
plt.ylabel('NLL-Loss')
plt.xlabel('Epochs')
plt.legend( loc='upper right')

# %%
Model4 = "10min_categorical_6classes_logScaled"
Model3 = "30min_LSTM_categorical_6classes_logScaled"

third = os.path.join(pwd,Model3)
fourth = os.path.join(pwd,Model4)

hist_first = os.path.join(third,Model3+"_history.json")
hist_second = os.path.join(fourth,Model4+"_history.json")

lstm = json.load(open(hist_first))
unet = json.load(open(hist_second))

# %%
plt.figure(figsize=(20, 10),dpi=100)

size=25
lw = 3
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (20,8),
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size,
          'ytick.labelsize': size,
          'axes.titlepad': 25}
plt.rcParams.update(params)


plt.plot(lstm['loss'][:35],label="LSTM train",lw=lw,color="blue")
plt.plot(lstm['val_loss'][:35],label="LSTM test",lw=lw,linestyle="--",color="blue")
plt.plot(unet['loss'][:35],label="Unet train",lw=lw,color="green")
plt.plot(unet['val_loss'][:35],label="Unet test",lw=lw,linestyle="--",color="green")
plt.title("Categorical 7 classes")
sns.set(style="darkgrid")
plt.ylim([0.325, 0.45])
plt.xlim([0, 35])
plt.ylabel('NLL-Loss')
plt.xlabel('Epochs')
plt.legend( loc='upper right')

# %%
LSTM_baseline = {0: {'TP': 60316923.0, 'TN': 0.0, 'FP': 363209477.0, 'FN': 0.0, 'TP_simple': 33308603.0, 'TN_simple': 335590946.0, 'FP_simple': 27618531.0, 'FN_simple': 27008320.0, 'total': 423526400, 'rain total': 363209477}, 1: {'TP': 60316923.0, 'TN': 0.0, 'FP': 363209477.0, 'FN': 0.0, 'TP_simple': 33308603.0, 'TN_simple': 335590946.0, 'FP_simple': 27618531.0, 'FN_simple': 27008320.0, 'total': 423526400, 'rain total': 363209477}, 2: {'TP': 55971744.0, 'TN': 284193228.0, 'FP': 79016249.0, 'FN': 4345179.0, 'TP_simple': 33308603.0, 'TN_simple': 335590946.0, 'FP_simple': 27618531.0, 'FN_simple': 27008320.0, 'total': 423526400, 'rain total': 363209477}, 3: {'TP': 53155220.0, 'TN': 306068524.0, 'FP': 57140953.0, 'FN': 7161703.0, 'TP_simple': 33308603.0, 'TN_simple': 335590946.0, 'FP_simple': 27618531.0, 'FN_simple': 27008320.0, 'total': 423526400, 'rain total': 363209477}, 4: {'TP': 51724291.0, 'TN': 313325957.0, 'FP': 49883520.0, 'FN': 8592632.0, 'TP_simple': 33308603.0, 'TN_simple': 335590946.0, 'FP_simple': 27618531.0, 'FN_simple': 27008320.0, 'total': 423526400, 'rain total': 363209477}, 5: {'TP': 50682556.0, 'TN': 317618920.0, 'FP': 45590
unet_baseline = {0: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 1: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 2: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 3: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 4: {'TP': 60319880.0, 'TN': 0.0, 'FP': 363206520.0, 'FN': 0.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 5: {'TP': 55418353.0, 'TN': 291089495.0, 'FP': 72117025.0, 'FN': 4901527.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 6: {'TP': 50134519.0, 'TN': 322575587.0, 'FP': 40630933.0, 'FN': 10185361.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 7: {'TP': 48186845.0, 'TN': 328294461.0, 'FP': 34912059.0, 'FN': 12133035.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 8: {'TP': 46060169.0, 'TN': 333787784.0, 'FP': 29418736.0, 'FN': 14259711.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 9: {'TP': 43046498.0, 'TN': 340163158.0, 'FP': 23043362.0, 'FN': 17273382.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 10: {'TP': 34432747.0, 'TN': 354311379.0, 'FP': 8895141.0, 'FN': 25887133.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 11: {'TP': 30308492.0, 'TN': 356866019.0, 'FP': 6340501.0, 'FN': 30011388.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 12: {'TP': 21675587.0, 'TN': 359738541.0, 'FP': 3467979.0, 'FN': 38644293.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 13: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 14: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 15: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 16: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 17: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 18: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 19: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 20: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 21: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 22: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 23: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 24: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 25: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 26: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 27: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 28: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 29: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 30: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 31: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 32: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 33: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 34: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 35: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 36: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 37: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 38: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 39: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}, 40: {'TP': 0.0, 'TN': 363206520.0, 'FP': 0.0, 'FN': 60319880.0, 'TP_simple': 33302547.0, 'TN_simple': 335626717.0, 'FP_simple': 27579803.0, 'FN_simple': 27017333.0, 'total': 423526400, 'rain total': 363206520}}

# %%
def plotAUC(baseline_dict,labels,title,lw=4):
    from sklearn.metrics import roc_curve, auc
    
    figure(num=None, figsize=(20, 15), dpi=100, facecolor='w', edgecolor='k')

    sns.set(style="ticks", context="talk")
    sns.set_style("darkgrid")
    plt.rcParams.update(params)
    for i,b in enumerate(baseline_dict):
        
        tp = []
        fp = []
        
        for key in b:
            base = b[key]
            tp.append(base["TP"]/(base["TP"]+base["FN"]) )
            fp.append(base["FP"]/(base["FP"]+base["FN"]))
    
        plt.plot(fp, tp,lw=lw, label='{} (area = {:.2f})'.format(labels[i],auc(fp,tp)))
    plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC - '+title)
    plt.legend(loc="lower right")
    plt.show()


plotAUC([unet_baseline,LSTM_baseline],["Unet ROC","LSTM ROC"],title="Zero-Inflated negative Binomial" )

# %%
LSTM_categorical = {0: {'TP': 60346007.0, 'TN': 0.0, 'FP': 363180393.0, 'FN': 0.0, 'TP_simple': 33309836.0, 'TN_simple': 335611621.0, 'FP_simple': 27568772.0, 'FN_simple': 27036171.0, 'total': 423526400, 'rain total': 363180393}, 1: {'TP': 57299501.0, 'TN': 274625852.0, 'FP': 88554541.0, 'FN': 3046506.0, 'TP_simple': 33309836.0, 'TN_simple': 335611621.0, 'FP_simple': 27568772.0, 'FN_simple': 27036171.0, 'total': 423526400, 'rain total': 363180393}, 2: {'TP': 54430721.0, 'TN': 304600793.0, 'FP': 58579600.0, 'FN': 5915286.0, 'TP_simple': 33309836.0, 'TN_simple': 335611621.0, 'FP_simple': 27568772.0, 'FN_simple': 27036171.0, 'total': 423526400, 'rain total': 363180393}, 3: {'TP': 51787504.0, 'TN': 319604671.0, 'FP': 43575722.0, 'FN': 8558503.0, 'TP_simple': 33309836.0, 'TN_simple': 335611621.0, 'FP_simple': 27568772.0, 'FN_
 423526400, 'rain total': 363178254}, 22: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 23: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 24: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 25: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 26: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 27: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 28: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 29: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 30: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 31: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 32: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 33: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 34: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 35: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 36: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 37: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 38: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 39: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}, 40: {'TP': 0.0, 'TN': 363178254.0, 'FP': 0.0, 'FN': 60348146.0, 'TP_simple': 33298509.0, 'TN_simple': 335631248.0, 'FP_simple': 27547006.0, 'FN_simple': 27049637.0, 'total': 423526400, 'rain total': 363178254}}


plotAUC([unet_categorical,LSTM_categorical],["Unet ROC","LSTM ROC"],title="Categorical 7 classes" )

# %%
from min30_LSTM_conv_znBinomial import *
get_LSTM_Model = getModel
MODELNAME_LSTM = MODELNAME

from min30_zeroInf_negative_Binomial import *
get_UNET_Model = getModel
MODELNAME_UNET = MODELNAME
# Out:
# Num GPUs: 1
# Num GPUs: 1

# %%
LSTM_model,checkpoint_lstm,modelpath_lstm,train,test = get_LSTM_Model()

history_path = os.path.join(modelpath_lstm,MODELNAME_LSTM+"_history")
laststate = getBestState(modelpath_lstm,history_path)
epoch = laststate["epoch"]
LSTM_model.load_weights(laststate["modelpath"])


UNET_model,checkpoint_unet,modelpath_unet,train,test = get_UNET_Model()

history_path = os.path.join(modelpath_unet,MODELNAME_UNET+"_history")
laststate = getBestState(modelpath_unet,history_path)
epoch = laststate["epoch"]
UNET_model.load_weights(laststate["modelpath"])

"""
predictions = UNET_model.layers[-2].output
UNET_model = Model(inputs=UNET_model.inputs, outputs=predictions)
UNET_model.summary()



predictions = LSTM_model.layers[-2].output
LSTM_model = Model(inputs=LSTM_model.inputs, outputs=predictions)
LSTM_model.summary()
"""
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 96, 96, 5)]  0
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 96, 96, 5)    230         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 96, 96, 5)    30          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 96, 96, 5)    230         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 96, 5)    230         conv2d_2[0][0]
# ...

# %%
import cv2 as cv
import numpy as np
import os
savepath="preds"
savepath_conmax="preds_contrastMax"

if not os.path.exists(savepath):
    os.mkdir(savepath)
    os.mkdir(savepath_conmax)


test.setWiggle_off()
cv.destroyAllWindows() 
cv.destroyAllWindows() 
windowname = 'OpenCvFrame'
cv.namedWindow(windowname)
save_nbr=0
lstm_prediction = []

for b,(x,y) in enumerate(test):
    batch_size = x.shape[0]
    
    for i in range(batch_size):
        a = np.array(LSTM_model(x[i:i+1,:,:,:]).mean())[0,:,:,0]
        filename = "{:05d}_30min.jpg".format(save_nbr)
        filename_cmax = "{:05d}_30min_contrastMax.jpg".format(save_nbr)
        #print("{:05d}".format(save_nbr),end="\r")
        cv.imwrite(os.path.join(savepath,filename),a)
        if a.max() > 1:
            cmax = (a / a.max()) * 255
        cv.imwrite(os.path.join(savepath_conmax,filename_cmax),cmax.astype(np.uint8))
        
        cv.imshow(windowname,cmax.astype(np.uint8))
        save_nbr +=1
        #print("\t\t\t",save_nbr,end="\r")
        if save_nbr >= 2000:
            bea = True
            break
        if cv.waitKey(25) & 0XFF == ord('q'):
            bea = True
            break
        
        #print(i,u_p.max(),l_p.max(),end="\r")
    #print("{:d}/{:d}".format(b,len(test)),end="\r")
    if bea:
        break
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-c0c1e1e61ecd> in <module>
#      29         if a.max() > 1:
#      30             cmax = (a / a.max()) * 255
# ---> 31         cv.imwrite(os.path.join(savepath_conmax,filename_cmax),cmax.astype(np.uint8))
#      32
#      33         cv.imshow(windowname,cmax.astype(np.uint8))
#
# NameError: name 'cmax' is not defined

# %%
def paramToImg(params):
    pred = np.array(params.prob(0))
    mask = (pred > 0.4)
    prediction = np.ones(pred.shape)
    prediction[mask] = 0
    print(prediction.shape)
    return prediction

# %%
"""
pwd_ = "/home/simon"

arr = []
for i in range(5):
    img = cv.imread(os.path.join(pwd_,str(i)+".png"),0)
    arr.append(img/255)
    
arr = np.array([arr])
arr = np.transpose(arr,(0,2,3,1))

prediction = np.array(UNET_model(arr).mean())[0,:,:,:]



prediction = (prediction / prediction.max())*255
cv.destroyAllWindows() 
windowname = 'OpenCvFrame'
cv.namedWindow(windowname)
cv.moveWindow(windowname,3500,800)
while True:
    cv.imshow(windowname,prediction.astype(np.uint8))
    
    if cv.waitKey(25) & 0XFF == ord('q'):
        break
        
cv.destroyAllWindows()
"""

# %%
import cv2 as cv
import numpy as np

c = cutOut([16,80,16,80])
unet_prediction = []
lstm_prediction = []
label           = []
atm             = []
test.setWiggle_off()
cv.destroyAllWindows() 
cv.destroyAllWindows() 
windowname = 'OpenCvFrame'
#cv.namedWindow(windowname)
#cv.moveWindow(windowname,0,0)

import os
savepath="znBinom_eval"

if not os.path.exists(savepath):
    os.mkdir(savepath)

bea = False
save_nbr = 0

def TPFP(pred,lab):

    eval_mask = np.zeros((*pred.shape,3))
    mask_TP = (pred >= 1) & (lab >= 1)
    mask_FP = (pred >= 1) & (lab < 1)
    mask = (pred < 1) & (lab >= 1)
    eval_mask[:,:,0] = mask
    eval_mask[:,:,1] = mask_TP
    eval_mask[:,:,2] = mask_FP
    return eval_mask * 255


for b,(x,y) in enumerate(test):
    batch_size = x.shape[0]
    
    for i in range(batch_size):
        unet_prediction.append(UNET_model(x[i:i+1,:,:,:]))
        lstm_prediction.append(LSTM_model(x[i:i+1,:,:,:]))
        
        #paramToImg(lstm_prediction[-1])
        atm.append(x[i,:,:,-1])
        label.append(y[i,:,:,:])
        
        
        ratm = c(atm[-1][:,:].copy()) * 255
        l = label[-1][:,:,0]
        #if ratm.max() > 0:
        #    ratm = ((ratm / ratm.max()) * 255)
        
        #if l.max() > 0:
        #    l = ((l/l.max())*255)
        
        

        a = ratm
        a = np.concatenate((a,l),axis=0)
        u_p = np.array(unet_prediction[-1].mean())
        l_p = np.array(lstm_prediction[-1].mean())
        
        #u_p_max = ((u_p/u_p.max())*255 ).astype(np.uint8)
        #l_p_max = ((l_p / l_p.max() )* 255).astype(np.uint8)
        #u_p = u_p.astype(np.uint8)
        
        a = np.concatenate((a,u_p[0,:,:,0]),axis=0)
        a = np.concatenate((a,l_p[0,:,:,0]),axis=0)
        
        u_p_max = u_p.copy()
        l_p_max = l_p.copy()
        d = ratm.copy()
        l_max = l.copy()
        
        
        l_p_mask = TPFP(l_p[0,:,:,0],l)
        u_p_mask = TPFP(u_p[0,:,:,0],l)
        
        if d.max() > 0:
            d = (d / d.max()) * 255
            
        if l_max.max() > 0:
            l_max = (l_max/l_max.max())*255
              
        if u_p_max.max() > 0:
            u_p_max = (u_p_max/u_p_max.max())*255

        if l_p_max.max() > 0:
            l_p_max = (l_p_max/l_p_max.max())*255
            
        d = np.concatenate((d,l_max ),axis=0)
        d = np.concatenate((d,u_p_max[0,:,:,0]),axis=0)
        d = np.concatenate((d,l_p_max[0,:,:,0]),axis=0)
        d = np.expand_dims(d, axis=-1)
        d = np.repeat(d,3,axis=-1)
        d = np.concatenate((d,u_p_mask))
        d = np.concatenate((d,l_p_mask))
        
        a = np.expand_dims(a, axis=-1)
        a = np.repeat(a,3,axis=-1)
        a = np.concatenate((a,u_p_mask))
        a = np.concatenate((a,l_p_mask))

        a [63:64,:] = 255
        a [(64*2)-1:64*2,:] = 255
        a [(64*3)-1:64*3,:] = 255
        a [(64*4)-1:64*4,:] = 255
        a [(64*5)-1:64*5,:] = 255
        d [63:64,:] = 255
        d [(64*2)-1:64*2,:] = 255
        d [(64*3)-1:64*3,:] = 255
        d [(64*4)-1:64*4,:] = 255
        d [(64*5)-1:64*5,:] = 255
        d2 = np.concatenate((a,d),axis=1)
        
        
        
        cv.imwrite(os.path.join(savepath,str(save_nbr)+".jpg"),a)
        cv.imwrite(os.path.join(savepath,str(save_nbr)+"_maxCont.jpg"),d[64:,:,:])
        
        
        inputs = x[i,:,:,-1]
        if inputs.max() > 0:
            inputs /= inputs.max()
            inputs *= 255
        inputs = np.expand_dims(inputs, axis=-1)
        inputs = np.repeat(inputs,3,axis=-1)
        
        inputs[14:80,14:16,:] = [0,0,255]
        inputs[14:80,78:80,:] = [0,0,255]
        
        inputs[14:16,15:80,:] = [0,0,255]
        inputs[78:80,15:80,:] = [0,0,255]
        
        
        cv.imwrite(os.path.join(savepath,str(save_nbr)+"_input_maxCont.jpg"),inputs)
        
        cv.imshow(windowname,inputs.astype(np.uint8))
        
        
        
        
        save_nbr +=1
        print("\t\t\t",save_nbr,end="\r")
        if save_nbr >= 2000:
            bea = True
            break
        if cv.waitKey(25) & 0XFF == ord('q'):
            bea = True
            break
        
        #print(i,u_p.max(),l_p.max(),end="\r")
    #print("{:d}/{:d}".format(b,len(test)),end="\r")
    if bea:
        break
cv.destroyAllWindows()
# Out:
# 			 2000

# %%
from min30_LSTM_conv_6classes_logScaled import *
get_LSTM_Model_categorical = getModel
MODELNAME_LSTM_categorical = MODELNAME

from min30_categorical_6classes_logScaled import *
get_UNET_Model_categorical = getModel
MODELNAME_UNET_categorical = MODELNAME
# Out:
# Num GPUs: 1
# Num GPUs: 1

# %%
LSTM_model,checkpoint_lstm,modelpath_lstm,train,test = get_LSTM_Model_categorical()
history_path = os.path.join(modelpath_lstm,MODELNAME_LSTM_categorical+"_history")
laststate = getBestState(modelpath_lstm,history_path)
epoch = laststate["epoch"]
LSTM_model.load_weights(laststate["modelpath"])


UNET_model,checkpoint_unet,modelpath_unet,train,test = get_UNET_Model_categorical()
history_path = os.path.join(modelpath_unet,MODELNAME_UNET_categorical+"_history")
laststate = getBestState(modelpath_unet,history_path)
epoch = laststate["epoch"]
UNET_model.load_weights(laststate["modelpath"])
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 96, 96, 5)]  0
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 96, 96, 5)    230         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 96, 96, 5)    30          input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 96, 96, 5)    230         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 96, 96, 5)    230         conv2d_29[0][0]
# ...

# %%
import cv2 as cv
import numpy as np

c = cutOut([16,80,16,80])
unet_prediction = []
lstm_prediction = []
label           = []
atm             = []
test.setWiggle_off()
cv.destroyAllWindows() 
cv.destroyAllWindows() 
windowname = 'OpenCvFrame'
#cv.namedWindow(windowname)
#cv.moveWindow(windowname,0,0)

import os
savepath="categorical_eval"

if not os.path.exists(savepath):
    os.mkdir(savepath)

bea = False
save_nbr = 0


for b,(x,y) in enumerate(test):
    batch_size = x.shape[0]
    
    for i in range(batch_size):
        unet_prediction.append(UNET_model(x[i:i+1,:,:,:]))
        lstm_prediction.append(LSTM_model(x[i:i+1,:,:,:]))
        
        pred = unet_prediction[-1]

        p = np.arange(1,7)
        m = pred.prob(p)
        max_ = np.argmax(m[:,:,:,1:],axis=-1)        
        
        
        unet_pred = max_.copy()
        unet_pred = np.expand_dims(unet_pred,axis=-1)
        pred = lstm_prediction[-1]
        p = np.arange(1,7)
        m = pred.prob(p)
        max_ = np.argmax(m[:,:,:,1:],axis=-1)        
        
        
        lstm_pred = max_.copy()
        lstm_pred = np.expand_dims(lstm_pred,axis=-1)
        atm.append(x[i,:,:,-1])
        label.append(y[i,:,:,:])
        
        
        ratm = c(atm[-1][:,:].copy()) * 255
        l = label[-1][:,:,0]

        

        a = ratm
        a = np.concatenate((a,l),axis=0)
        u_p = np.array(unet_pred)
        l_p = np.array(lstm_pred)
        
        #u_p_max = ((u_p/u_p.max())*255 ).astype(np.uint8)
        #l_p_max = ((l_p / l_p.max() )* 255).astype(np.uint8)
        #u_p = u_p.astype(np.uint8)
        
        a = np.concatenate((a,u_p[0,:,:,0]),axis=0)
        a = np.concatenate((a,l_p[0,:,:,0]),axis=0)
        
        u_p_max = u_p.copy()
        l_p_max = l_p.copy()
        d = ratm.copy()
        l_max = l.copy()
        
        
        l_p_mask = TPFP(l_p[0,:,:,0],l)
        u_p_mask = TPFP(u_p[0,:,:,0],l)
        
        if d.max() > 0:
            d = (d / d.max()) * 255
            
        if l_max.max() > 0:
            l_max = (l_max/l_max.max())*255
              
        if u_p_max.max() > 0:
            u_p_max = (u_p_max/u_p_max.max())*255

        if l_p_max.max() > 0:
            l_p_max = (l_p_max/l_p_max.max())*255
            
        d = np.concatenate((d,l_max ),axis=0)
        d = np.concatenate((d,u_p_max[0,:,:,0]),axis=0)
        d = np.concatenate((d,l_p_max[0,:,:,0]),axis=0)
        d = np.expand_dims(d, axis=-1)
        d = np.repeat(d,3,axis=-1)
        d = np.concatenate((d,u_p_mask))
        d = np.concatenate((d,l_p_mask))
        
        a = np.expand_dims(a, axis=-1)
        a = np.repeat(a,3,axis=-1)
        a = np.concatenate((a,u_p_mask))
        a = np.concatenate((a,l_p_mask))

        a [63:64,:] = 255
        a [(64*2)-1:64*2,:] = 255
        a [(64*3)-1:64*3,:] = 255
        a [(64*4)-1:64*4,:] = 255
        a [(64*5)-1:64*5,:] = 255
        d [63:64,:] = 255
        d [(64*2)-1:64*2,:] = 255
        d [(64*3)-1:64*3,:] = 255
        d [(64*4)-1:64*4,:] = 255
        d [(64*5)-1:64*5,:] = 255
        d2 = np.concatenate((a,d),axis=1)
        
        
        
        cv.imwrite(os.path.join(savepath,str(save_nbr)+"_cat_.jpg"),a)
        cv.imwrite(os.path.join(savepath,str(save_nbr)+"_cat_maxCont.jpg"),d[64:,:,:])

        
        inputs = x[i,:,:,-1]
        if inputs.max() > 0:
            inputs /= inputs.max()
            inputs *= 255
        inputs = np.expand_dims(inputs, axis=-1)
        inputs = np.repeat(inputs,3,axis=-1)
        
        inputs[14:80,14:16,:] = [0,0,255]
        inputs[14:80,78:80,:] = [0,0,255]
        
        inputs[14:16,15:80,:] = [0,0,255]
        inputs[78:80,15:80,:] = [0,0,255]
        
        
        cv.imwrite(os.path.join(savepath,str(save_nbr)+"_input_maxCont.jpg"),inputs)
        
        cv.imshow(windowname,inputs.astype(np.uint8))
        
        
        save_nbr +=1
        
        print("\t\t\t",save_nbr,end="\r")
        if save_nbr >= 2000:
            bea = True
            break
            
        if cv.waitKey(25) & 0XFF == ord('q') :
            bea = True
            break
        
        #print(i,u_p.max(),l_p.max(),end="\r")
    #print("{:d}/{:d}".format(b,len(test)),end="\r")
    if bea:
        break
cv.destroyAllWindows()
# Out:
# 			 191

# %%
import pandas as pd
def plotConfusionMat(baseline,t):
    
    
    print("Parameter : {:.2f}".format(t/20))
    baseline = baseline[t]
    false_neg = baseline["FN"]
    false_pos = baseline["FP"]
    true_pos = baseline["TP"]
    true_neg = baseline["TN"]
    
    simple_false_neg = baseline["FN_simple"]
    simple_false_pos = baseline["FP_simple"]
    simple_true_pos = baseline["TP_simple"]
    simple_true_neg = baseline["TN_simple"]
    
    print(simple_false_neg)
    print(simple_false_pos)
    print(simple_true_pos)
    print(simple_true_neg)
    plt.figure(figsize = (4,4))
    size=12
    lw = 3
    params = {'legend.fontsize': 'x-large',
          'figure.figsize': (20,8),
          'axes.labelsize': size,
          'axes.titlesize': size,
          'xtick.labelsize': size,
          'ytick.labelsize': size,
          'axes.titlepad': 25}
    plt.rcParams.update(params)
    #mat = np.array([[false_neg.sum(),false_pos.sum()],[true_neg.sum(),true_pos.sum()]])
    mat = np.array([[true_neg / (true_neg + false_pos),false_pos / (true_neg + false_pos) ],\
                    [false_neg / (false_neg + true_pos),true_pos/ (false_neg + true_pos)]])
    total = mat.sum()
    
    
    df_cm = pd.DataFrame(mat,index = ["Actual 0","Actual 1"],columns=["Predicted 0","Predicted 1"])
    sns.heatmap(df_cm, annot=True,vmin=0.0, vmax=1.0)
    plt.show()
    
    plt.figure(figsize = (4,4))
    print("Simple Baseline")
    
    mat_simple = np.array([[simple_true_neg / (simple_true_neg + simple_false_pos),simple_false_pos / (simple_true_neg + simple_false_pos)],\
                           [simple_false_neg / (simple_false_neg + simple_true_pos),simple_true_pos/ (simple_false_neg + simple_true_pos)]])
    total = mat.sum()
    df_cm = pd.DataFrame(mat_simple,index = ["Actual 0","Actual 1"],columns=["Predicted 0","Predicted 1"])
    sns.heatmap(df_cm, annot=True,vmin=0.0, vmax=1.0)
    plt.show()

    print(len(baseline))

    
plotConfusionMat(LSTM_categorical,t=10)
# Out:
# Parameter : 0.50
# 27036171.0
# 27568772.0
# 33309836.0
# 335611621.0
# Simple Baseline
# 10

# %%
plotConfusionMat(unet_categorical,t=10)
# Out:
# Parameter : 0.50
# 27049637.0
# 27547006.0
# 33298509.0
# 335631248.0
# Simple Baseline
# 10

# %%
plotConfusionMat(LSTM_baseline,t=10)
# Out:
# Parameter : 0.50
# 27008320.0
# 27618531.0
# 33308603.0
# 335590946.0
# Simple Baseline
# 10

# %%
plotConfusionMat(unet_baseline,t=10)
# Out:
# Parameter : 0.50
# 27017333.0
# 27579803.0
# 33302547.0
# 335626717.0
# Simple Baseline
# 10
